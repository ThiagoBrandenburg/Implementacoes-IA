# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_theme()

# %%
df = pd.read_excel('docs\MotorUniversal_2k_5kHz_SemNorm.xlsx')

# %%
df.head()
# Out:
#    Estado  Corrente  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0       0  0.717573    0.714725    0.704585    0.694305    0.687011
# 1       0  0.719402    0.717330    0.708022    0.698305    0.691041
# 2       0  0.723090    0.721113    0.711632    0.701274    0.692945
# 3       0  0.729627    0.726485    0.715613    0.704214    0.695404
# 4       0  0.714636    0.714388    0.706626    0.698127    0.691818
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 1991  \
# 0    0.683188    0.682031    0.682287    0.682855  ...      22.574360
# 1    0.686480    0.683860    0.682345    0.681356  ...      21.606304
# 2    0.687295    0.683872    0.682021    4.548630  ...      21.920634
# 3    0.689836    0.686908    0.685656    0.685570  ...      21.762202
# 4    0.688184    0.686566    0.686016    0.685919  ...      22.371510
#
#    Unnamed: 1992  Unnamed: 1993  Unnamed: 1994  Unnamed: 1995  Unnamed: 1996  \
# ...

# %%
indices = ['Estado'] + ['c{number}'.format(number=i) for i in range(1,1001)] + ['t{number}'.format(number=i) for i in range(1,1001)]

# %%
df.columns = indices

# %%
df.head()
# Out:
#    Estado        c1        c2        c3        c4        c5        c6  \
# 0       0  0.717573  0.714725  0.704585  0.694305  0.687011  0.683188
# 1       0  0.719402  0.717330  0.708022  0.698305  0.691041  0.686480
# 2       0  0.723090  0.721113  0.711632  0.701274  0.692945  0.687295
# 3       0  0.729627  0.726485  0.715613  0.704214  0.695404  0.689836
# 4       0  0.714636  0.714388  0.706626  0.698127  0.691818  0.688184
#
#          c7        c8        c9  ...       t991       t992       t993  \
# 0  0.682031  0.682287  0.682855  ...  22.574360  22.291788  22.200832
# 1  0.683860  0.682345  0.681356  ...  21.606304  21.749150  21.913914
# 2  0.683872  0.682021  4.548630  ...  21.920634  22.191567  22.503530
# 3  0.686908  0.685656  0.685570  ...  21.762202  21.882131  21.835883
# 4  0.686566  0.686016  0.685919  ...  22.371510  22.625730  22.591585
#
#         t994       t995       t996       t997       t998       t999      t1000
# ...

# %%
df.iloc[0][1:1000].plot()
# Out:
# <AxesSubplot:>

# %%
df.iloc[0][1001:2000]
# Out:
# t1      24.521245
# t2      24.362290
# t3      23.990888
# t4      23.592605
# t5      23.162054
#           ...
# t995    21.933806
# t996    21.704434
# t997    21.518837
# t998    21.423986
# t999    21.415594
# Name: 0, Length: 999, dtype: float64

# %%
df_corrente = df.iloc[:,1:1000]
df_tensao = df.iloc[:,1001:2001]

# %%
df_tensao.head()
# Out:
#           t1         t2         t3         t4         t5         t6  \
# 0  24.521245  24.362290  23.990888  23.592605  23.162054  22.661129
# 1  24.476110  24.308086  23.952220  23.557495  23.093905  22.554693
# 2  24.456592  24.184072  23.755055  23.280734  22.764188  22.248571
# 3  24.547889  24.331171  23.891840  23.386809  22.851967  22.312061
# 4  24.573959  24.388299  23.969512  23.465090  22.916798  22.365382
#
#           t7         t8         t9        t10  ...       t991       t992  \
# 0  22.147862  21.735410  21.500079  21.448782  ...  22.574360  22.291788
# 1  22.022636  21.606941  21.403315  21.450779  ...  21.606304  21.749150
# 2  21.829966  21.598151  21.577764  21.724964  ...  21.920634  22.191567
# 3  21.850312  21.555870  21.474495  21.576895  ...  21.762202  21.882131
# 4  21.904258  21.626954  21.575632  21.720554  ...  22.371510  22.625730
#
#         t993       t994       t995       t996       t997       t998  \
# ...

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.head()
# Out:
#    Estado        c1        c2        c3        c4        c5        c6  \
# 0       0  0.717573  0.714725  0.704585  0.694305  0.687011  0.683188
# 1       0  0.719402  0.717330  0.708022  0.698305  0.691041  0.686480
# 2       0  0.723090  0.721113  0.711632  0.701274  0.692945  0.687295
# 3       0  0.729627  0.726485  0.715613  0.704214  0.695404  0.689836
# 4       0  0.714636  0.714388  0.706626  0.698127  0.691818  0.688184
#
#          c7        c8        c9  ...       t991       t992       t993  \
# 0  0.682031  0.682287  0.682855  ...  22.574360  22.291788  22.200832
# 1  0.683860  0.682345  0.681356  ...  21.606304  21.749150  21.913914
# 2  0.683872  0.682021  4.548630  ...  21.920634  22.191567  22.503530
# 3  0.686908  0.685656  0.685570  ...  21.762202  21.882131  21.835883
# 4  0.686566  0.686016  0.685919  ...  22.371510  22.625730  22.591585
#
#         t994       t995       t996       t997       t998       t999      t1000
# ...

# %%
'''
df.fillna(df.rolling(4,axis=0).mean,axis=0,inplace=True)
df_corrente.fillna(df_corrente.rolling(4,axis=0).mean,axis=0,inplace=True)
'''

# %%
df.shape
# Out:
# (500, 2001)

# %%
def knnline4(df: pd.DataFrame):
    (rows,columns) = df.shape
    for i in range(rows):
        for j in range(100,columns,-100)

# %%
type(df.rolling(4,axis=0))
# Out:
# pandas.core.window.rolling.Rolling

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.head()
# Out:
#   Estado        c1        c2        c3        c4        c5        c6  \
# 0    0.0  0.717573  0.714725  0.704585  0.694305  0.687011  0.683188
# 1    0.0  0.719402   0.71733  0.708022  0.698305  0.691041   0.68648
# 2    0.0   0.72309  0.721113  0.711632  0.701274  0.692945  0.687295
# 3    0.0  0.729627  0.726485  0.715613  0.704214  0.695404  0.689836
# 4    0.0  0.714636  0.714388  0.706626  0.698127  0.691818  0.688184
#
#          c7        c8        c9  ...       t991       t992       t993  \
# 0  0.682031  0.682287  0.682855  ...   22.57436  22.291788  22.200832
# 1   0.68386  0.682345  0.681356  ...  21.606304   21.74915  21.913914
# 2  0.683872  0.682021   4.54863  ...  21.920634  22.191567   22.50353
# 3  0.686908  0.685656   0.68557  ...  21.762202  21.882131  21.835883
# 4  0.686566  0.686016  0.685919  ...   22.37151   22.62573  22.591585
#
#         t994       t995       t996       t997       t998       t999      t1000
# ...

# %%
df.iloc[0:10,5:9]
# Out:
#          c5                                                 c6        c7  \
# 0  0.687011                                           0.683188  0.682031
# 1  0.691041                                            0.68648  0.683860
# 2  0.692945                                           0.687295  0.683872
# 3  0.695404                                           0.689836  0.686908
# 4  0.691818                                           0.688184  0.686566
# 5  0.679207                                           0.673953  0.671190
# 6  0.673444                                           0.668689  0.666877
# 7  0.683641  <bound method Rolling.mean of Rolling [window=...  0.675341
# 8  0.683628                                           0.678881  0.676684
# 9  0.683422                                           0.679671  0.678144
#
#          c8
# 0  0.682287
# 1  0.682345
# 2  0.682021
# 3  0.685656
# 4  0.686016
# 5  0.670066
# 6  0.667309
# 7  0.674119
# 8  0.676065
# 9  0.677745

# %%
df['c6'][7]
# Out:
# <bound method Rolling.mean of Rolling [window=4,center=False,axis=0,method=single]>

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
def normalize(x):
    norm_x = MinMaxScaler().fit(x)

# %%
type(df_tensao.iloc[20])
# Out:
# pandas.core.series.Series

# %%
def min_max_norm(x:pd.Series):
    return (x - x.min())/(x.max() - x.min())

# %%
def apply_norm(datf:pd.DataFrame):
    return datf.apply(min_max_norm,axis=0)

# %%
df_tensao = apply_norm(df_tensao)

# %%
df_tensao.head()
# Out:
#          t1        t2        t3        t4        t5        t6        t7  \
# 0  0.055430  0.056704  0.077060  0.128421  0.194830  0.211532  0.149655
# 1  0.053101  0.053796  0.074530  0.125487  0.187140  0.196692  0.130901
# 2  0.052095  0.047142  0.061628  0.102358  0.149935  0.154014  0.102047
# 3  0.056804  0.055034  0.070579  0.111223  0.159840  0.162865  0.105094
# 4  0.058149  0.058099  0.075661  0.117765  0.167156  0.170299  0.113173
#
#          t8        t9       t10  ...      t991      t992      t993      t994  \
# 0  0.135625  0.114561  0.144642  ...  0.503166  0.520293  0.474169  0.461303
# 1  0.116132  0.099226  0.144970  ...  0.360316  0.429259  0.429447  0.463391
# 2  0.114798  0.126872  0.190022  ...  0.406700  0.503480  0.521350  0.540763
# 3  0.108382  0.110507  0.165693  ...  0.383321  0.451568  0.417285  0.385515
# 4  0.119168  0.126535  0.189297  ...  0.473232  0.576316  0.535075  0.490151
#
#        t995      t996      t997      t998      t999     t1000
# ...

# %%
df_tensao.iloc[0].plot()
# Out:
# <AxesSubplot:>

# %%
df_corrente = apply_norm(df_corrente)

# %%
from sklearn.model_selection import train_test_split

# %%
df.iloc[:][2:3].head()
# Out:
#   Estado       c1        c2        c3        c4        c5        c6        c7  \
# 2    0.0  0.72309  0.721113  0.711632  0.701274  0.692945  0.687295  0.683872
#
#          c8       c9  ...       t991       t992      t993       t994  \
# 2  0.682021  4.54863  ...  21.920634  22.191567  22.50353  22.636686
#
#         t995       t996       t997       t998       t999      t1000
# 2  22.477095  22.179683  21.903873  21.712412  21.651748  21.751566
#
# [1 rows x 2001 columns]

# %%
from scipy.fft import fft, ifft

# %%
tensao = df_tensao.loc[0].to_numpy()

# %%
x = fft(tensao)

# %%
plt.plot(x)
# Out:
# c:\Users\thiag\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
print(x)
# Out:
# [ 3.58303298e+02-0.00000000e+00j -1.56083686e+01-2.66758442e+01j
#  -4.50928035e+01-5.18663696e+01j  2.05231857e+01+1.61795782e+01j
#   5.99260464e-01-6.36252110e+00j -1.15204175e+01+2.50422845e+01j
#   1.81559839e+00+1.41459509e+00j -4.44837862e+00+3.93213819e+00j
#  -4.28792312e+00+8.50533215e+00j  4.71548172e+00+7.93143272e+00j
#  -1.94597589e+00+3.82749106e+00j  4.79089470e+00+5.42776110e+00j
#  -2.47596294e+00+3.50083104e+00j  1.33426602e-01+3.94632196e+00j
#   3.04377167e+00+5.95813683e+00j  1.95506857e+00-3.64636000e+00j
#   1.12156607e-01+6.22294668e+00j  2.71372168e+00+5.48763351e+00j
#  -9.11068665e+00-1.81638806e+00j  4.61785995e-02+3.13117807e+00j
#   8.04771987e+00+1.63145198e+01j  4.36143316e+00+1.06138061e+01j
#   7.78085404e-01+3.27558105e+00j -1.36005737e+00-6.11259604e+00j
#   5.37034273e+00-7.58467743e+00j  1.98703356e+00+1.58791753e+01j
#  -1.33204587e+01+5.84523406e+00j  5.22550796e+00+4.41930706e+00j
# ...

# %%
X = df.iloc[:][1:2001]
y = df.iloc[:][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\thiag\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# c:\Users\thiag\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\Users\thiag\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

print(xdados_treino.shape)
epocas = 10

model = keras.Sequential([
    keras.layers.Flatten(input_shape=(2,1000)),
    keras.layers.Dense(1024,activation = "relu"),
    keras.layers.Dense(16,activation = "sigmoid")
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

teste = model.fit(xdados_treino,
                xlabel_treino,
                validation_data=(xdados_validacao, xlabel_validacao),
                epochs=epocas)
print('TESTE')
model.evaluate(xdados_teste, xlabel_teste)
